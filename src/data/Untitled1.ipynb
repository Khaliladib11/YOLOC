# %%
from bdd import BDD
from pathlib import Path
import matplotlib.pyplot as plt
import random

# %%
objects_to_detect = ['pedestrian', 'rider', 'truck', 'bus', 'motorcycle', 'bicycle', 'car', 'traffic light']

bdd_params = {
    "image_root": Path('../../dataset'),
    "detection_classes": objects_to_detect,
    "stage": 'train',
    "det_task": True,
    "de_seg_task": True,
    "ll_seg_task": True,
}

bdd = BDD(**bdd_params)

# %%
idx = random.randint(0, len(bdd))
bdd.display_image(idx = 0, boxes=True, de_seg=True, ll_seg=False)
# Out:
# <PIL.Image.Image image mode=L size=1280x720 at 0x1F55D203EE0>

# %%
import torch

# %%
model = torch.hub.load('hustvl/yolop', 'yolop', pretrained=True)
# Out:
# C:\Users\Khaliladib\anaconda3\envs\yoloc\lib\site-packages\torch\hub.py:266: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/hustvl/yolop/zipball/main" to C:\Users\Khaliladib/.cache\torch\hub\main.zip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ...

# %%
det_out, da_seg_out,ll_seg_out = model(img)
